# %%
import pandas as pd 
import numpy as np 
from IPython.display import HTML

# %%
players = (pd.read_csv("../static/CSV/players_2023.csv") 
           .drop(labels=['Rk', 'Player-additional'], axis=1)
)
players
# Out:
#                       Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# 0                Luka Dončić  PG   24  DAL  70  70  37.5  11.5  23.6  0.487
# 1      Giannis Antetokounmpo  PF   29  MIL  73  73  35.2  11.5  18.8  0.611
# 2    Shai Gilgeous-Alexander  PG   25  OKC  75  75  34.0  10.6  19.8  0.535
# 3              Jalen Brunson  PG   27  NYK  77  77  35.4  10.3  21.4  0.479
# 4               Devin Booker  PG   27  PHO  68  68  36.0   9.4  19.2  0.492
# ..                       ...  ..  ...  ...  ..  ..   ...   ...   ...    ...
# 235                KJ Martin  SF   23  TOT  60   2  12.4   1.6   3.0  0.536
# 236            Dwight Powell   C   32  DAL  63   9  13.3   1.1   1.7  0.679
# 237               Zeke Nnaji  PF   23  DEN  58   0   9.9   1.2   2.6  0.463
# 238                  JT Thor  PF   21  CHO  63   3  12.4   1.3   2.9  0.437
# 239              Dalen Terry  SG   21  CHI  59   2  11.5   1.2   2.7  0.439
#
# ...

# %%
# players_html = HTML(players.to_html(classes='table table-stripped')) 
# players_html
# display(players_html)
# players_html = players.to_html() 
players_html = players.to_html(classes='table table-stripped')
players_html
# Out:
# '<table border="1" class="dataframe table table-stripped">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Player</th>\n      <th>Pos</th>\n      <th>Age</th>\n      <th>Tm</th>\n      <th>G</th>\n      <th>GS</th>\n      <th>MP</th>\n      <th>FG</th>\n      <th>FGA</th>\n      <th>FG%</th>\n      <th>3P</th>\n      <th>3PA</th>\n      <th>3P%</th>\n      <th>2P</th>\n      <th>2PA</th>\n      <th>2P%</th>\n      <th>eFG%</th>\n      <th>FT</th>\n      <th>FTA</th>\n      <th>FT%</th>\n      <th>ORB</th>\n      <th>DRB</th>\n      <th>TRB</th>\n      <th>AST</th>\n      <th>STL</th>\n      <th>BLK</th>\n      <th>TOV</th>\n      <th>PF</th>\n      <th>PTS</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Luka Dončić</td>\n      <td>PG</td>\n      <td>24</td>\n      <td>DAL</td>\n      <td>70</td>\n      <td>70</td>\n      <td>37.5</td>\n      <td>11.5</td>\n      <td>23.6</td>\n      <td>0.487</td>\n      <td>4.1</td>\n      <t
# ...

# %%
text_file = open("../static/Table.html", "w", encoding='utf-8') 
text_file.write(players_html)  
text_file 
text_file.close()
