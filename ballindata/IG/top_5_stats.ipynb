# %%
import sqlalchemy, numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import os, sys 
from django.conf import settings

# %%
engine = sqlalchemy.create_engine("sqlite:///../DB/ballbase.db") 
pd.read_sql('master_as', con=engine)
# Out:
#                 Player   Season Pos   Age       Tm    GP   MPG    FG   FGA  \
# 0        Abdul Jeelani  1979-80  SF  25.0      POR  77.0  16.7   3.7   7.3
# 1       Adrian Dantley  1979-80  SF  24.0      UTA  68.0  39.3  10.7  18.6
# 2           Al Skinner  1979-80  SG  27.0      PHI   2.0   5.0   0.5   1.0
# 3         Alex English  1979-80  SF  26.0  IND-DEN  78.0  30.8   7.1  14.3
# 4        Allan Bristow  1979-80  SF  28.0      UTA  82.0  28.1   4.6   9.6
# ...                ...      ...  ..   ...      ...   ...   ...   ...   ...
# 19370      Zach LaVine  2023-24  SG  28.0      CHI  25.0  34.9   6.8  15.0
# 19371   Zavier Simpson  2023-24  PG  26.0      MEM   7.0  23.0   2.4   7.7
# 19372       Zeke Nnaji  2023-24  PF  23.0      DEN  58.0   9.9   1.2   2.6
# 19373  Ziaire Williams  2023-24  SF  22.0      MEM  51.0  20.4   2.9   7.4
# 19374  Zion Williamson  2023-24  PF  23.0      NOP  70.0  31.5   8.9  15.6
#
#         FG%  ...   PER  STL%  TOV%  TRB%   TS%  USG%  VORP    WS  WS/48   AS
# 0      51.0  ...  18.7   1.5  15.2  11.5  56.3  24.6   1.1   3.8  0.141  0.0
# 1      57.6  ...  24.3   1.8  13.5  11.3  63.5  27.8   3.8  10.5  0.189  1.0
# 2      50.0  ...  -0.6   0.0  50.0   0.0  50.0  16.0   0.0   0.0 -0.152  0.0
# 3      49.7  ...  18.0   1.4  14.8  13.1  53.6  23.4   1.5   5.3  0.105  0.0
# 4      48.0  ...  16.6   1.9  16.7  13.0  53.4  20.0   1.5   4.4  0.091  0.0
# ...     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 19370  45.2  ...  15.1   1.2  11.0   8.3  57.8  23.8   0.5   1.5  0.080  0.0
# 19371  31.5  ...   6.3   2.1  15.2   6.8  37.7  17.5  -0.2  -0.2 -0.046  0.0
# 19372  46.3  ...  12.4   1.3  13.3  12.1  52.8  15.4  -0.2   1.2  0.099  0.0
# 19373  39.7  ...   9.3   1.7  13.8   9.5  51.1  19.7  -0.6   0.2  0.010  0.0
# 19374  57.0  ...  22.8   1.7  12.8  10.2  61.0  29.7   3.3   7.5  0.164  0.0
#
# [19375 rows x 70 columns]
