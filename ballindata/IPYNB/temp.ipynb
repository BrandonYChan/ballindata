# %%
import pandas as pd, numpy as np, sqlalchemy 
pd.set_option('display.max_columns', None)

# %%
engine = sqlalchemy.create_engine('sqlite:///../DB/ballbase.db')

# %%
temp = pd.read_sql('master_1992_93', con=engine) 
temp
# Out:
#                    Player Pos   Age   Tm     G    GS    MP   FG   FGA    FG%  \
# 0              A.C. Green  PF  29.0  LAL  82.0  55.0  34.4  4.6   8.6  0.537
# 1              Adam Keefe  PF  22.0  ATL  82.0   6.0  18.9  2.3   4.6  0.500
# 2          Alaa Abdelnaby  PF  24.0  TOT  75.0  52.0  17.5  3.3   6.3  0.518
# 3                Alan Ogg   C  25.0  TOT   6.0   0.0   4.8  0.8   2.2  0.385
# 4            Alec Kessler  PF  26.0  MIA  40.0   2.0  10.4  1.4   3.1  0.467
# ..                    ...  ..   ...  ...   ...   ...   ...  ...   ...    ...
# 385       Willie Anderson  SG  26.0  SAS  38.0   7.0  14.7  2.1   4.9  0.430
# 386         Willie Burton  SF  24.0  MIA  26.0   8.0  17.3  2.1   5.4  0.383
# 387       Winston Garland  PG  28.0  HOU  66.0   4.0  15.2  2.3   5.2  0.443
# 388       Xavier McDaniel  PF  29.0  BOS  82.0  27.0  27.0  5.6  11.3  0.495
# 389  Šarūnas Marčiulionis  SF  28.0  GSW  30.0   8.0  27.9  5.9  10.9  0.543
#
# ...

# %%
temp['Age'].astype(int)
# Out:
# 0      24
# 1      23
# 2      20
# 3      28
# 4      27
#        ..
# 567    28
# 568    26
# 569    23
# 570    22
# 571    23
# Name: Age, Length: 572, dtype: int32
